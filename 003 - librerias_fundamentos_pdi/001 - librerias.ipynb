# %%
# !pip install scikit-image pillow -q # https://scikit-image.org/

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage as ski
from PIL import Image, ImageFont, ImageDraw
from PIL import ImageChops
import PIL.ImageStat as stat
from skimage import io
from skimage import color, exposure, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import invert, random_noise, montage
import matplotlib.image as mpimg

# %%
from skimage.exposure import histogram
coins = ski.data.coins()
hist, hist_centers = ski.exposure.histogram(coins)

# %%
plt.imshow(coins, cmap='gray')

# %%
coffee = ski.data.coffee()
plt.imshow(coffee)

# %%
# !wget https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/81/11/huggingface-logo-venture.component.crop-2by1-xl.ts=1747140549427.png/content/adobe-cms/us/en/think/topics/hugging-face/jcr:content/root/leadspace_container/leadspace_article
# Out:
# --2025-08-27 22:22:06--  https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/81/11/huggingface-logo-venture.component.crop-2by1-xl.ts=1747140549427.png/content/adobe-cms/us/en/think/topics/hugging-face/jcr:content/root/leadspace_container/leadspace_article
# Resolving www.ibm.com (www.ibm.com)... 23.61.43.57, 2600:1407:7400:d87::1e89, 2600:1407:7400:d85::1e89
# Connecting to www.ibm.com (www.ibm.com)|23.61.43.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63566 (62K) [image/png]
# Saving to: ‘leadspace_article’
#
# leadspace_article   100%[===================>]  62.08K  --.-KB/s    in 0.02s
#
# 2025-08-27 22:22:06 (2.65 MB/s) - ‘leadspace_article’ saved [63566/63566]

# %%
im = Image.open("/content/leadspace_article") #

# %%
plt.imshow(im)
